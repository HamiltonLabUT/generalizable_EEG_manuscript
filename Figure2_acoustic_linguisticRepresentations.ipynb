# %%
# Set up the notebook, import the libraries we need

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

 
from run_STRF_analysis import *

# %%
#Define path
data_dir = os.path.abspath('../data')

subject_list = create_subject_list(data_dir+'/participants')

stimulus_class = ['MovieTrailers', 'TIMIT']
print(subject_list)
save_dir = os.path.abspath('../figures') #save data
# Out:
# ['MT0001', 'MT0002', 'MT0003', 'MT0004', 'MT0005', 'MT0006', 'MT0008', 'MT0009', 'MT0010', 'MT0011', 'MT0012', 'MT0013', 'MT0014', 'MT0015', 'MT0016', 'MT0017']

# %%
data_dir = '/Users/maansidesai/Box/MovieTrailersTask/Data/EEG/Participants'
save_dir = '/Users/maansidesai/Box/generalizable_EEG_manuscript/figures/Revisions_062321/pdfs'
subject_list = ['MT0001', 'MT0002', 'MT0003', 'MT0004', 'MT0005', 'MT0006', 'MT0008', 'MT0009', 'MT0010', 'MT0011', 'MT0012', 'MT0013', 'MT0014', 'MT0015', 'MT0016', 'MT0017']

# %% [markdown]
# ## Create Convex-hull plots showing the overlap and distrubtion of features for each condition

# %% [markdown]
# #### Fig. 2A (TIMIT)

# %%
# data_dir = '/Users/maansidesai/Box/MovieTrailersTask/Data/EEG/Participants'
timit_subj_list = ['MT0001', 'MT0002', 'MT0003', 'MT0004', 'MT0005', 'MT0006', 'MT0008', 'MT0009', 'MT0010', 'MT0011', 'MT0012', 'MT0013', 'MT0014', 'MT0015', 'MT0016']
convexHull('TIMIT', timit_subj_list, data_dir,save_dir,
          save_fig=True)
# Out:
# TIMIT
# [121 377  25  50 356 435 237 429 239 291  11 121]
# [121  11 168 237 225  31 334 318 320 121]
# [121  81 101  20 237 435  76 134 485 121]

# %% [markdown]
# #### Fig. 2B (Movie Trailers)

# %%
convexHull('MT', subject_list, data_dir,save_dir,save_fig=True)
# Out:
# trailers
# [494 556 326 324 337 332 369   4  11 446 458 444 602 275 483 562 494]
# [556 536 494 441 458 446   8  99 332 337 556]
# [577 446 458  14 415 487 494 536 556 577]

# %% [markdown]
# ## Variance paritioning (unique variance), identifying the amount of unique feature contribution for each condition for model performance

# %% [markdown]
# #### Fig. 2C (TIMIT)

# %%
#3-way venn diagram

variance_partition = var_partition('TIMIT', timit_subj_list, data_dir, opacity=0.4)

venn_diagram = create_vennDiagram(timit_subj_list, 'TIMIT', variance_partition,save_dir,
                                  save_fig=False)
# Out:
# /Users/maansidesai/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1011: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   full_model = corr_full[sig_corrs_full] #sig elec corrs for full model
# /Users/maansidesai/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1012: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   envs_U_pitch = corr_envspitch[sig_corrs_full]
# /Users/maansidesai/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1013: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pitch_U_phnfeat = corr_pitchphnfeat[sig_corrs_full]
# /Users/maansidesai/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1014: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   envs_U_phnfeat = corr_envsphnfeat[sig_corrs_full]
# /Users/maansidesai/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1015: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   envs_only = corr_envs[sig_corrs_full]
# /Users/maansidesai/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1016: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pitch_only = corr_pitch[sig_corrs_full]
# /Users/maansidesai/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1017: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phnfeat_only = corr_phnfeat[sig_corrs_full]
# 0 / 25
# (7, 25)
# 0 / 47
# (7, 47)
# 0 / 35
# (7, 35)
# 0 / 38
# (7, 38)
# 0 / 40
# (7, 40)
# 0 / 37
# (7, 37)
# 0 / 59
# (7, 59)
# 0 / 32
# (7, 32)
# 0 / 5
# (7, 5)
# 0 / 28
# (7, 28)
# 0 / 39
# (7, 39)
# 0 / 44
# (7, 44)
# 0 / 7
# (7, 7)
# 0 / 41
# (7, 41)
# 0 / 22
# (7, 22)

# %%
#barplot
feature_variance_Barplot('TIMIT', timit_subj_list, venn_diagram, save_dir,
                        opacity=0.4,save_fig=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-19cf5161dcb8> in <module>
#       1 #barplot
# ----> 2 feature_variance_Barplot('TIMIT', timit_subj_list, venn_diagram, save_dir,
#       3                         opacity=0.4,save_fig=False)
#
# ~/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py in feature_variance_Barplot(stimulus_class, subject_list, venn_diagram, save_dir, opacity, save_fig)
#    1121
#    1122         for idx, s in enumerate(subject_list):
# -> 1123                 unique_var_pitch.append(venn_diagram[idx][2]) #envs_U_phnfeat
#    1124                 unique_var_phnfeat.append(venn_diagram[idx][1]) #envs_U_pitch
#    1125                 unique_var_envs.append(venn_diagram[idx][0]) #pitch_U_phnfeat
#
# IndexError: tuple index out of range

# %% [markdown]
# #### Fig. 2D (Movie Trailers)

# %%
#3-way venn diagram
variance_partition = var_partition('MT', subject_list, opacity=0.4,
                  data_dir=data_dir)
venn_diagram = create_vennDiagram(subject_list, 'MT', variance_partition,
                                  save_fig=True, save_dir=save_dir)
# Out:
# 0 / 18
# (7, 18)
# 0 / 56
# (7, 56)
# 0 / 42
# (7, 42)
# 0 / 43
# (7, 43)
# 0 / 40
# (7, 40)
# 0 / 45
# (7, 45)
# 0 / 55
# (7, 55)
# 0 / 39
# (7, 39)
# 0 / 39
# (7, 39)
# 0 / 34
# (7, 34)
# 0 / 33
# (7, 33)
# 0 / 31
# (7, 31)
# 0 / 15
# (7, 15)
# 0 / 54
# (7, 54)
# 0 / 31
# (7, 31)
# 0 / 37
# (7, 37)

# %%
#barplot
feature_variance_Barplot('MT', subject_list, venn_diagram, 
                        opacity=0.4,save_fig=True, save_dir=save_dir)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-fc7f7d7acd40> in <module>
#       1 #barplot
# ----> 2 feature_variance_Barplot('MT', subject_list, venn_diagram,
#       3                         opacity=0.4,save_fig=True, save_dir=save_dir)
#
# ~/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py in feature_variance_Barplot(stimulus_class, subject_list, venn_diagram, save_dir, opacity, save_fig)
#    1121
#    1122         for idx, s in enumerate(subject_list):
# -> 1123                 unique_var_pitch.append(venn_diagram[idx][2]) #envs_U_phnfeat
#    1124                 unique_var_phnfeat.append(venn_diagram[idx][1]) #envs_U_pitch
#    1125                 unique_var_envs.append(venn_diagram[idx][0]) #pitch_U_phnfeat
#
# IndexError: tuple index out of range

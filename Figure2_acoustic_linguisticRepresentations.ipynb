# %%
# Set up the notebook, import the libraries we need

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

 
from run_STRF_analysis import *

# %%
#Define path
user = 'md42732'
path='/Users/%s/Box/generalizable_EEG_manuscript/data' %(user) #where the giant .h5 file lives (fullEEGmatrix.h5)
# data_dir = os.path.join('../data')

subject_list = create_subject_list(path+'/participants') #create subject list of all participant folders (MT0001-MT0017)
print(subject_list)
# Out:
# ['MT0001', 'MT0002', 'MT0003', 'MT0004', 'MT0005', 'MT0006', 'MT0008', 'MT0009', 'MT0010', 'MT0011', 'MT0012', 'MT0013', 'MT0014', 'MT0015', 'MT0016', 'MT0017']

# %%
data_dir = os.path.dirname(path) + '/data/participants'
print(data_dir)
save_dir = os.path.dirname(path) + '/figures'
# Out:
# /Users/md42732/Box/generalizable_EEG_manuscript/data/participants

# %% [markdown]
# ## Create Convex-hull plots showing the overlap and distrubtion of features for each condition

# %% [markdown]
# #### Fig. 2A (TIMIT)

# %%
# data_dir = '/Users/maansidesai/Box/MovieTrailersTask/Data/EEG/Participants'
timit_subj_list = ['MT0001', 'MT0002', 'MT0003', 'MT0004', 'MT0005', 'MT0006', 'MT0008', 'MT0009', 'MT0010', 'MT0011', 'MT0012', 'MT0013', 'MT0014', 'MT0015', 'MT0016']
convexHull('TIMIT', timit_subj_list, data_dir,save_dir,
          save_fig=False)
# Out:
# TIMIT
# [121 377  25  50 356 435 237 429 239 291  11 121]
# [121  11 168 237 225  31 334 318 320 121]
# [121  81 101  20 237 435  76 134 485 121]

# %% [markdown]
# #### Fig. 2B (Movie Trailers)

# %%
convexHull('MT', subject_list, data_dir,save_dir,save_fig=False)
# Out:
# trailers
# [494 556 326 324 337 332 369   4  11 446 458 444 602 275 483 562 494]
# [556 536 494 441 458 446   8  99 332 337 556]
# [577 446 458  14 415 487 494 536 556 577]

# %% [markdown]
# ## Variance paritioning (unique variance), identifying the amount of unique feature contribution for each condition for model performance

# %% [markdown]
# #### Fig. 2C (TIMIT)

# %%
#3-way venn diagram

variance_partition = var_partition('TIMIT', timit_subj_list, data_dir, opacity=0.4)

venn_diagram = create_vennDiagram(timit_subj_list, 'TIMIT', variance_partition,save_dir,
                                  save_fig=False)
# Out:
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1083: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   sig_corrs_full = ([np.where (p_val_full[0] < 0.05)])
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1084: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   full_model = corr_full[sig_corrs_full] #sig elec corrs for full model
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1085: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   envs_U_pitch = corr_envspitch[sig_corrs_full]
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1086: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pitch_U_phnfeat = corr_pitchphnfeat[sig_corrs_full]
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1087: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   envs_U_phnfeat = corr_envsphnfeat[sig_corrs_full]
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1088: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   envs_only = corr_envs[sig_corrs_full]
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1089: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pitch_only = corr_pitch[sig_corrs_full]
# 0 / 25
# (7, 25)
# 0 / 47
# (7, 47)
# 0 / 35
# (7, 35)
# 0 / 38
# (7, 38)
# 0 / 40
# (7, 40)
# 0 / 37
# (7, 37)
# 0 / 59
# (7, 59)
# 0 / 32
# (7, 32)
# 0 / 5
# (7, 5)
# 0 / 28
# (7, 28)
# 0 / 39
# (7, 39)
# 0 / 44
# (7, 44)
# 0 / 7
# (7, 7)
# 0 / 41
# (7, 41)
# 0 / 22
# (7, 22)

# %%
np.shape(venn_diagram[0])
# Out:
# (15, 7)

# %%
#barplot
feature_variance_Barplot('TIMIT', timit_subj_list, venn_diagram[0], save_dir,
                        opacity=0.4,save_fig=False)

# %% [markdown]
# #### Fig. 2D (Movie Trailers)

# %%
#3-way venn diagram
variance_partition = var_partition('MT', subject_list,data_dir, opacity=0.4)
venn_diagram = create_vennDiagram(subject_list, 'MT', variance_partition,save_dir,save_fig=False)
# Out:
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1083: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   sig_corrs_full = ([np.where (p_val_full[0] < 0.05)])
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1084: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   full_model = corr_full[sig_corrs_full] #sig elec corrs for full model
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1085: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   envs_U_pitch = corr_envspitch[sig_corrs_full]
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1086: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pitch_U_phnfeat = corr_pitchphnfeat[sig_corrs_full]
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1087: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   envs_U_phnfeat = corr_envsphnfeat[sig_corrs_full]
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1088: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   envs_only = corr_envs[sig_corrs_full]
# /Users/md42732/Desktop/git/generalizable_EEG_manuscript/run_STRF_analysis.py:1089: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pitch_only = corr_pitch[sig_corrs_full]
# 0 / 18
# (7, 18)
# 0 / 56
# (7, 56)
# 0 / 42
# (7, 42)
# 0 / 43
# (7, 43)
# 0 / 40
# (7, 40)
# 0 / 45
# (7, 45)
# 0 / 55
# (7, 55)
# 0 / 39
# (7, 39)
# 0 / 39
# (7, 39)
# 0 / 34
# (7, 34)
# 0 / 33
# (7, 33)
# 0 / 31
# (7, 31)
# 0 / 15
# (7, 15)
# 0 / 54
# (7, 54)
# 0 / 31
# (7, 31)
# 0 / 37
# (7, 37)

# %%
#barplot
feature_variance_Barplot('MT', subject_list, venn_diagram[0], save_dir,
                        opacity=0.4,save_fig=False)
